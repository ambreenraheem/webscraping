# %% [markdown]
# # Ambreen Abdul Raheem
# ## Microsoft Power BI Data Analyst
# ### (Upwork Freelancer)
# ### Email: ambreen.upwork.27@gmail.com
# ### LinkedIn: https://www.linkedin.com/in/ambreen-abdul-raheem-122509300/
# ### GitHub: https://github.com/ambreenraheem

# %% [markdown]
# # webscraping with pandas

# %% [markdown]
# 🌐 If you're a data analyst who loves working with new and real-world datasets, web scraping is a powerful way to explore and analyze fresh data directly from the source.
#
# By using Python’s amazing libraries — like Pandas, Seaborn, NumPy, lxml, Requests, BeautifulSoup4, Scrapy, Selenium, OpenPyXL, and HTML5lib — you can collect data from websites based on your client’s needs and turn it into valuable insights.
#
# And with Power BI’s stunning visualizations, you can transform that data into powerful dashboards and reports that drive decisions and tell compelling stories.
#
# We live in a world full of data — every individual, business, and platform has its own unique and interesting datasets. For me, uncovering and analyzing these datasets doubles the excitement and joy of working in data analytics.
#
# Check out the latest updates and resources on web scraping through my link. Let’s make data analysis more meaningful and fun! 🚀📊

# %%
import pandas as pd
import numpy as np

# %%
# !pip install lxml requests beautifulsoup4 scrapy selenium openpy

# %%
# !pip install html5lib

# %%
# !pip install seaborn matplotlib plotly

# %% [markdown]
# ### You can also create the required environment.txt file using the following command:

# %%
# !pip freeze
# Out:
# absl-py==1.4.0
# accelerate==1.6.0
# aiobotocore==2.22.0
# aiohappyeyeballs==2.6.1
# aiohttp==3.11.15
# aioitertools==0.12.0
# aiosignal==1.3.2
# alabaster==1.0.0
# albucore==0.0.24
# albumentations==2.0.6
# ale-py==0.11.0
# altair==5.5.0
# annotated-types==0.7.0
# antlr4-python3-runtime==4.9.3
# anyio==4.9.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# array_record==0.7.2
# arviz==0.21.0
# astropy==7.0.2
# astropy-iers-data==0.2025.5.12.0.38.29
# astunparse==1.6.3
# atpublic==5.1
# attrs==25.3.0
# audioread==3.0.1
# autograd==1.8.0
# Automat==25.4.16
# babel==2.17.0
# backcall==0.2.0
# backports.tarfile==1.2.0
# beautifulsoup4==4.13.4
# betterproto==2.0.0b6
# bigframes==2.4.0
# bigquery-magics==0.9.0
# bleach==6.2.0
# blinker==1.9.0
# blis==1.3.0
# blobfile==3.0.0
# blosc2==3.3.2
# bokeh==3.7.3
# botocore==1.37.3
# Bottleneck==1.4.2
# bqplot==0.12.44
# branca==0.8.1
# build==1.2.2.post1
# CacheControl==0.14.3
# cachetools==5.5.2
# catalogue==2.0.10
# certifi==2025.4.26
# ...

# %%
# create a requirement.txt file
# !pip freeze > requirements.txt

# %% [markdown]
# # World Population Data scraped from Wikipedia.com

# %%
# step 2: Load the URL for world population on wikipedia
url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"

# %%
# step 3: Read the HTML tables from the URL
df = pd.read_html(url)

# %%
# step 4: Check the number of tables found
print(f"Number of tables found: {len(df)}")
# Out:
# Number of tables found: 3

# %%
# step 5: Display the first few rows of the first table
df[0].head(10)
# Out:
#         Location  Population % of world         Date  \
# 0          World  8142273940       100%  15 May 2025
# 1          India  1413324000      17.3%   1 Mar 2025
# 2          China  1408280000      17.2%  31 Dec 2024
# 3  United States   340110988       4.2%   1 Jul 2024
# 4      Indonesia   282477584       3.5%  30 Jun 2024
# 5       Pakistan   241499431       3.0%   1 Mar 2023
# 6        Nigeria   223800000       2.7%   1 Jul 2023
# 7         Brazil   212583750       2.6%   1 Jul 2024
# 8     Bangladesh   169828911       2.1%  14 Jun 2022
# 9         Russia   146028325       1.8%   1 Jan 2025
#
#   Source (official or from the United Nations) Notes
# 0                          UN projection[1][3]   NaN
# 1                       Official projection[4]   [b]
# 2                         Official estimate[5]   [c]
# 3                         Official estimate[6]   [d]
# 4                National annual projection[7]   NaN
# 5                        2023 census result[8]   [e]
# ...

# %%
print(df[0].shape)
# Out:
# (240, 6)

# %%
print(df[0].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Location                                      240 non-null    object
#  1   Population                                    240 non-null    int64
#  2   % of world                                    240 non-null    object
#  3   Date                                          240 non-null    object
#  4   Source (official or from the United Nations)  240 non-null    object
#  5   Notes                                         33 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 11.4+ KB
# None

# %%
print(df[0].isnull().sum())
# Out:
# Location                                          0
# Population                                        0
# % of world                                        0
# Date                                              0
# Source (official or from the United Nations)      0
# Notes                                           207
# dtype: int64

# %%
print(df[0].columns)
# Out:
# Index(['Location', 'Population', '% of world', 'Date',
#        'Source (official or from the United Nations)', 'Notes'],
#       dtype='object')

# %%
print(df[0].dtypes)
# Out:
# Location                                        object
# Population                                       int64
# % of world                                      object
# Date                                            object
# Source (official or from the United Nations)    object
# Notes                                           object
# dtype: object

# %%
df[1].head(5)
# Out:
#   vteLists of countries by population statistics  \
# 0                                         Global
# 1                          Continents/subregions
# 2                               Intercontinental
# 3                             Cities/urban areas
# 4                                Past and future
#
#     vteLists of countries by population statistics.1
# 0  Current population United Nations Demographics...
# 1  Africa Antarctica Asia Europe North America Ca...
# 2  Americas Arab world Commonwealth of Nations Eu...
# 3  World cities National capitals Megacities Mega...
# 4  Past and future population World population es...

# %%
print(df[1].shape)
# Out:
# (13, 2)

# %%
print(df[1].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   vteLists of countries by population statistics    13 non-null     object
#  1   vteLists of countries by population statistics.1  13 non-null     object
# dtypes: object(2)
# memory usage: 340.0+ bytes
# None

# %%
print(df[1].isnull().sum())
# Out:
# vteLists of countries by population statistics      0
# vteLists of countries by population statistics.1    0
# dtype: int64

# %%
print(df[1].columns)
# Out:
# Index(['vteLists of countries by population statistics', 'vteLists of countries by population statistics.1'], dtype='object')

# %%
# df[0] plot
from matplotlib import pyplot as plt
_df_9['Population'].plot(kind='line', figsize=(8, 4), title='Population')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# df[0] plot
from matplotlib import pyplot as plt
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Date'].value_counts()
    for x_label, grp in _df_11.groupby('% of world')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('% of world')
_ = plt.ylabel('Date')

# %%
print(df[1].dtypes)
# Out:
# vteLists of countries by population statistics      object
# vteLists of countries by population statistics.1    object
# dtype: object

# %%
# storing df[0] data in csv
print(df[0].to_csv('world_population.csv', index=False))
# Out:
# None

# %%
# storing df[1] data in csv
print(df[1].to_csv('world_population_by_region.csv', index=False))
# Out:
# None

# %% [markdown]
# # World Population Data scraped from Worldometers.com

# %% [markdown]
# ### We need to use the requests library to download the HTML content of the page. The requests library allows us to send HTTP requests and receive responses from web servers. It is a powerful and easy-to-use library that simplifies the process of making HTTP requests in Python.

# %%
# step 1: Import the required libraries
import pandas as pd

# step 2: Load the URL
url2 = 'https://www.worldometers.info/world-population/population-by-country/'

# %%
# step 3: Fetch the HTML content with headers and read the HTML table into a DataFrame
import requests
# headers to avoid being blocked
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# %%
# headers are important to avoid being blocked by the server
response = requests.get(url2, headers=headers)
response.raise_for_status()  # Raise an error for bad status codes

# %%
df2 = pd.read_html(response.text)
# Out:
# <ipython-input-112-05db072ea665>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df2 = pd.read_html(response.text)

# %%
# step 4: Check the number of tables
print(f"Number of tables found: {len(df2)}")
# step 5: Display the first few rows of the first table
df2[0].head()
# Out:
# Number of tables found: 1
#    # Country (or dependency)  Population (2025) Yearly Change  Net Change  \
# 0  1                   India         1463865525         0.89%    12929734
# 1  2                   China         1416096094        −0.23%  −3,225,184
# 2  3           United States          347275807         0.54%     1849236
# 3  4               Indonesia          285721236         0.79%     2233305
# 4  5                Pakistan          255219554         1.57%     3950390
#
#    Density (P/Km²)  Land Area (Km²) Migrants (net)  Fert. Rate  Median Age  \
# 0              492          2973190       −495,753        1.94        28.8
# 1              151          9388211       −268,126        1.02        40.1
# 2               38          9147420        1230663        1.62        38.5
# 3              158          1811570        −39,509        2.10        30.4
# 4              331           770880     −1,235,336        3.50        20.6
#
#   Urban Pop % World Share
# ...

# %%
print(df2[0].shape)
# Out:
# (233, 12)

# %%
print(df2[0].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   #                        233 non-null    int64
#  1   Country (or dependency)  233 non-null    object
#  2   Population (2025)        233 non-null    int64
#  3   Yearly Change            233 non-null    object
#  4   Net Change               233 non-null    object
#  5   Density (P/Km²)          233 non-null    int64
#  6   Land Area (Km²)          233 non-null    int64
#  7   Migrants (net)           233 non-null    object
#  8   Fert. Rate               233 non-null    float64
#  9   Median Age               233 non-null    float64
#  10  Urban Pop %              210 non-null    object
#  11  World Share              233 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 22.0+ KB
# None

# %%
print(df2[0].columns)
# Out:
# Index(['#', 'Country (or dependency)', 'Population (2025)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Median Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
print(df2[0].isnull().sum())
# Out:
# #                           0
# Country (or dependency)     0
# Population (2025)           0
# Yearly Change               0
# Net Change                  0
# Density (P/Km²)             0
# Land Area (Km²)             0
# Migrants (net)              0
# Fert. Rate                  0
# Median Age                  0
# Urban Pop %                23
# World Share                 0
# dtype: int64

# %%
# storing df[0] data in csv
print(df2[0].to_csv('world_population_(worldometers).csv', index=False))
# Out:
# None
